# %% [markdown]
# DATA VISUALIZATION WITH PANDAS AND MATPLOTLIB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./datasets/data.csv")

dataset = pd.DataFrame(data)
clean_dataset = dataset.fillna("1", inplace=True)

# print(clean_dataset)
# print(dataset.to_string())
# print(clean_dataset.to_string())

dataset.plot()

plt.show()

# %% [markdown]
# SCATTER PLOT

# %%
dataset.plot(kind="scatter", x="Duration", y ="Calories")
plt.show()

# %% [markdown]
# HISTOGRAM

# %%
dataset["Maxpulse"].plot(kind="hist")

plt.show()
