# %% [markdown]
# Lorem ipsum, dolor sit amet consectetur adipisicing elit. Numquam hic qui quis cumque odit blanditiis placeat cum dolores necessitatibus voluptatibus inventore, omnis eum nobis! Veniam suscipit quisquam itaque natus neque?

# %%
import pandas as pd
import numpy as np

# %%
tree = pd.read_csv("./pandas_csv_1.csv")
print(tree)
# Out:
#                Timestamp  1. What is your age? 2. Gender  \
# 0     4/18/2022 19:18:47                  21.0      Male
# 1     4/18/2022 19:19:28                  21.0    Female
# 2     4/18/2022 19:25:59                  21.0    Female
# 3     4/18/2022 19:29:43                  21.0    Female
# 4     4/18/2022 19:33:31                  21.0    Female
# ..                   ...                   ...       ...
# 476   5/21/2022 23:38:28                  24.0      Male
# 477    5/22/2022 0:01:05                  26.0    Female
# 478   5/22/2022 10:29:21                  29.0    Female
# 479   7/14/2022 19:33:47                  21.0      Male
# 480  11/12/2022 13:16:50                  53.0      Male
#
#     3. Relationship Status 4. Occupation Status  \
# 0        In a relationship   University Student
# 1                   Single   University Student
# 2                   Single   University Student
# 3                   Single   University Student
# ...

# %%
name = input("Enter name?")
print("Hello " + name)
# Out:
# Hello abnna

# %%
data = {
    "calories": [420, 380, 390], 
    "duration": [50, 40, 45]
}

data_frame = pd.DataFrame(data)
print(data_frame)

# Locating rows
print(data_frame.loc[1])
print(data_frame.loc[[1, 2]])
# Adding labels to index
datframe = pd.DataFrame(data, index=["Day1", "Day2", "Day3"])
print(datframe)
# Locate Named Indexes
print(datframe.loc["Day1"])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# calories    380
# duration     40
# Name: 1, dtype: int64
#    calories  duration
# 1       380        40
# 2       390        45
#       calories  duration
# Day1       420        50
# Day2       380        40
# Day3       390        45
# calories    420
# duration     50
# Name: Day1, dtype: int64

# %% [markdown]
# Loading Files into Dataframes

# %%
bolu = pd.read_csv("./datasets/pandas_csv_1.csv")
boluDataFrame = pd.DataFrame(bolu)

print(boluDataFrame)
print(boluDataFrame.head(7))
# Out:
#                Timestamp  1. What is your age? 2. Gender  \
# 0     4/18/2022 19:18:47                  21.0      Male
# 1     4/18/2022 19:19:28                  21.0    Female
# 2     4/18/2022 19:25:59                  21.0    Female
# 3     4/18/2022 19:29:43                  21.0    Female
# 4     4/18/2022 19:33:31                  21.0    Female
# ..                   ...                   ...       ...
# 476   5/21/2022 23:38:28                  24.0      Male
# 477    5/22/2022 0:01:05                  26.0    Female
# 478   5/22/2022 10:29:21                  29.0    Female
# 479   7/14/2022 19:33:47                  21.0      Male
# 480  11/12/2022 13:16:50                  53.0      Male
#
#     3. Relationship Status 4. Occupation Status  \
# 0        In a relationship   University Student
# 1                   Single   University Student
# 2                   Single   University Student
# 3                   Single   University Student
# ...

# %%
readCsv = pd.read_csv("./datasets/data.csv")
print(readCsv.head(10))
print(readCsv.tail(10))
print(readCsv.info())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# ...

# %% [markdown]
# Data Cleaning

# %%
df = pd.read_csv("./datasets/data.csv")
df.dropna(inplace=True)

print(df.to_string())
print(df.info())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...
